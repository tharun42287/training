# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=sns.load_dataset('taxis')
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
sns.barplot(x='color',y='total',data=df,color='red',estimator='var')
plt.show()

# %%
sns.barplot(x='color',y='total',data=df,color='pink',estimator='std')
plt.show()

# %%
sns.barplot(x='color',y='total',data=df,color='silver',estimator='sum')
plt.show()

# %%
sns.barplot(x='color',y='total',data=df,color='black',estimator='mean')
plt.show()

# %%
sns.barplot(x='color',y='total',data=df,color='green',estimator='median')
plt.show()

# %%
sns.barplot(x='payment',y='total',data=df,color='blue',estimator='median')
plt.show()
plt.tight_layout()

# %%
sns.barplot(x='payment',y='total',data=df,color='yellow',estimator='mean')
plt.show()
plt.tight_layout()

# %%
sns.histplot(x=df['fare'])
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.histplot(x=df['fare'],color='green')
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.histplot(x=df['fare'],color='red')
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.histplot(x=df['fare'],color='green',hue=df['color'])
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.histplot(x=df['fare'],color='green',hue=df['payment'])
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.histplot(x=df['fare'],palette=['white','black'],hue=df['payment'])
plt.show()

# %%
sns.violinplot(x=df['fare'],y=df['payment'])
# Out:
# <Axes: xlabel='fare', ylabel='payment'>

# %%
sns.violinplot(x=df['fare'],y=df['payment'],palette=['g','y'])
# Out:
# <Axes: xlabel='fare', ylabel='payment'>

# %%
sns.violinplot(x=df['fare'],y=df['payment'],palette=['g','y'])
plt.show()

# %%
sns.boxplot(x=df['fare'])
# Out:
# <Axes: xlabel='fare'>

# %%
sns.boxplot(x=df['fare'],y=df['payment'],palette=['red','blue'])
# Out:
# <Axes: xlabel='fare', ylabel='payment'>

# %%
sns.scatterplot(x=df['fare'],y=df['total'],palette=['b','y'],hue=df['payment'])
plt.show()
plt.tight_layout()

# %%
sns.stripplot(x=df['color'],y=df['fare'],palette=['g','b'])
plt.show()
plt.tight_layout()

# %%
sns.stripplot(x=df['fare'],y=df['color'],palette=['g','b'])
plt.show()
plt.tight_layout()

# %%
iris_data=sns.load_dataset('iris')
df=sns.load_dataset('taxis')

# %%
sns.scatterplot(x=iris_data['sepal_length'],y=iris_data['petal_length'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.scatterplot(x=iris_data['sepal_length'],y=iris_data['petal_length'],hue=iris_data['species'],palette=['r','g','y'])
plt.show()

# %%
sns.stripplot(x=iris_data['species'],y=iris_data['sepal_width'],palette=['r','g','y'])
# Out:
# <Axes: xlabel='species', ylabel='sepal_width'>

# %%
sns.scatterplot(x=df['payment'],y=df['tip'],palette=['r','g',])
# Out:
# <Axes: xlabel='payment', ylabel='tip'>

# %%
sns.lineplot(x=df['tip'],y=df['fare'],color='red',)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.lineplot(x=df['total'],y=df['fare'])
plt.show()

# %%
sns.lineplot(x=df['total'],y=df['fare'],hue=df['payment'],palette=['red','green'])
plt.show()

# %%
df[['payment','color']].value_counts()
# Out:
# payment      color
# credit card  yellow    4000
# cash         yellow    1412
# credit card  green      577
# cash         green      400
# Name: count, dtype: int64

# %%
df['color'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       yellow
# 1       yellow
# 2       yellow
# 3       yellow
# 4       yellow
#          ...
# 6428     green
# 6429     green
# 6430     green
# 6431     green
# 6432     green
# Name: color, Length: 6433, dtype: object>

# %%
df['payment'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       credit card
# 1              cash
# 2       credit card
# 3       credit card
# 4       credit card
#            ...
# 6428    credit card
# 6429    credit card
# 6430           cash
# 6431    credit card
# 6432    credit card
# Name: payment, Length: 6433, dtype: object>

# %%
sns.countplot(x=df['payment'])
# Out:
# <Axes: xlabel='payment', ylabel='count'>

# %%
sns.countplot(x=df['payment'],hue=df['color'],palette=['lightgreen','red'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.countplot(x=df['payment'],hue=df['color'],palette=['lightgreen','red'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(fig_size(10,50))
sns.countplot(x=df['payment'],hue=df['color'],palette=['lightgreen','red','yellow'])
